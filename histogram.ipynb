# %%
##Load result csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
file=r"F:\Projets\Gaby project\NeuralnetworkBPestimation\CNN_result_mat_larger\2022-25-08_alexnet_training_mat_2_test_results.csv"
# df = pd.read_csv('D:/Implementation/NeuralnetworkBPestimation/result/test_results.csv')
df = pd.read_csv(file)
df1=df.DBP_error
df1=np.abs(df1)

plt.hist(df1, bins=10, alpha=0.5, label='dbp')
plt.title('Histogram of error(DBP)')
plt.ylabel('Frequency')
plt.xlabel('Error(mmHg)')
# Out:
# Text(0.5, 0, 'Error(mmHg)')

# %%
import numpy as np
# df = pd.read_csv('D:/Implementation/NeuralnetworkBPestimation/result/test_results.csv')
df = pd.read_csv(r"F:\Projets\Gaby project\NeuralnetworkBPestimationTorch\logs\experiments\base_mat_mlp_21\test_results.csv")
df2=df.SBP_error
df2=np.abs(df2)
plt.hist(df2, bins=10, alpha=0.5, label='sbp')
plt.title('Histogram of error(SBP)')
plt.ylabel('Frequency')
plt.xlabel('Error(mmHg)')
# Out:
# Text(0.5, 0, 'Error(mmHg)')

# %%
res_file=r'F:\Projets\Gaby project\NeuralnetworkBPestimation\CNN_result_mat\baseline_cnn_test_results.csv'

# %%
import numpy as np
df = pd.read_csv(res_file)
df_error_dbp= np.abs(df['DBP_est']-df['DBP_true'])
dbp_mean=np.mean(df_error_dbp)
print(dbp_mean)
plt.hist(df_error_dbp, bins=10, alpha=0.5, label='dbp')
plt.title('Histogram of error(DBP)')
plt.ylabel('Frequency')
plt.xlabel('Error(mmHg)')
# Out:
# 9.314019666666647
# Text(0.5, 0, 'Error(mmHg)')

# %%
df = pd.read_csv(res_file)
df_error_sbp= np.abs(df['SBP_est']-df['SBP_true'])
#print(df_error_dbp.head(40))
plt.hist(df_error_sbp, bins=10, alpha=0.5, label='sbp')
plt.title('Histogram of error(SBP)')
plt.ylabel('Frequency')
plt.xlabel('Error(mmHg)')
# Out:
# Text(0.5, 0, 'Error(mmHg)')

# %%
import numpy as np
df = pd.read_csv('D:/Implementation/NeuralnetworkBPestimation/CNN_result_7s/logs/results/2022-18-08_alexnet_training_kaggle_test_results.csv')
df_error_dbp= df['DBP_est']-df['DBP_true']
#print(df_error_dbp.head(30))
plt.hist(df_error_dbp, bins=10, alpha=0.5, label='dbp')
plt.title('Histogram of error(DBP)')
plt.ylabel('Frequency')
plt.xlabel('Error(mmHg)')
# Out:
# Text(0.5, 0, 'Error(mmHg)')

# %%
import numpy as np
df = pd.read_csv('D:/Implementation/NeuralnetworkBPestimation/CNN_result_7s/logs/results/2022-18-08_alexnet_training_kaggle_test_results.csv')
df_error_dbp= df['DBP_est']-df['DBP_true']
print(df_error_dbp.head(30))
plt.hist(df_error_dbp, bins=10, alpha=0.5, label='dbp')
plt.title('Histogram of error(DBP)')
plt.ylabel('Frequency')
plt.xlabel('Error(mmHg)')
